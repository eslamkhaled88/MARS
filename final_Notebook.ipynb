# %% [markdown]
# # Chunk Number 1:

# %% [markdown]
# # **Installation & Packages**

# %%
! sudo apt update && sudo apt install ffmpeg
! pip install ffmpeg-python
! pip install --upgrade ffmpeg-python
! pip install faster_whisper
! pip install python-docx
! pip install requests
! pip install numpy
! pip install tqdm
! pip install gs
! pip install openai
! pip install line_profiler

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:5 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,004 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,269 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,343 kB]
# ...

# %% [markdown]
# # **CSV File Editing & Panel Master Creating**
# ###### Add the "courses.csv" file

# %%
import os
import pandas as pd
from google.colab import drive

# Step 1: Define the path where you want to create the folder
folder_path = "/content/drive/MyDrive/Final_Automation"

# Check if the folder already exists
if not os.path.exists(folder_path):
    # Create the folder if it doesn't exist
    os.makedirs(folder_path)
    print(f"Folder '{folder_path}' created successfully.")
else:
    print(f"Folder '{folder_path}' already exists.")

# Step 2: Create the Panel Master Folder in Google Drive
folder_name = "/content/drive/MyDrive/Final_Automation/panel_master"

if not os.path.exists(folder_name):
    # Create the folder
    os.makedirs(folder_name)
    print(f"Folder '{folder_name}' created successfully.")
else:
    print(f"Folder '{folder_name}' already exists.")

# Step 3: Read the CSV file from Google Drive
file_path = "/content/drive/MyDrive/courses.csv"
df = pd.read_csv(file_path)

# Step 4: Extract the Course Name
def extract_course_name(mp3_url):
    # Split the URL by "/"
    parts = mp3_url.split("/")

    # Extract the part before ".mp3" and get the last part (course name)
    course_name = parts[5].replace('_', ' ').title()

    return course_name

df["Course_Name"] = df["Mp3"].apply(extract_course_name)

# Step 5: Save the updated DataFrame to a new CSV file in Google Drive
output_file_path = "/content/drive/MyDrive/Final_Automation/courses_list.csv"
df.to_csv(output_file_path, index=False)

print(f"DataFrame saved to '{output_file_path}' in your Google Drive.")

# Step 6: Remove the original "courses.csv" file
if os.path.exists(file_path):
    os.remove(file_path)
    print(f"Original 'courses.csv' file removed.")
else:
    print(f"Original 'courses.csv' file not found.")
# Out:
# Folder '/content/drive/MyDrive/Final_Automation' already exists.
# Folder '/content/drive/MyDrive/Final_Automation/panel_master' already exists.
# DataFrame saved to '/content/drive/MyDrive/Final_Automation/courses_list.csv' in your Google Drive.
# Original 'courses.csv' file removed.

# %% [markdown]
# # Chunk Number 2:

# %% [markdown]
# # **Creating Folders for Unique Course Names**

# %%
import csv
from google.colab import drive

def create_course_folders(csv_file_path, panel_master_drive_path):

    # Check if panel_master directory exists in Google Drive
    panel_master_path = panel_master_drive_path
    if not os.path.exists(panel_master_path):
        print("Error: panel_master directory not found in Google Drive.")
        return

    # Create a set to store unique course names
    unique_course_names = set()

    # Read the CSV file from Google Drive and extract course names
    csv_file_drive_path = csv_file_path
    with open(csv_file_drive_path, mode="r", encoding="utf-8") as csv_file:
        csv_reader = csv.DictReader(csv_file, delimiter=",")
        for row in csv_reader:
            course_name = row['Course_Name']
            unique_course_names.add(course_name)

    # Create folders for unique course names in Google Drive
    for course_name in unique_course_names:
        course_folder_path = os.path.join(panel_master_path, course_name)
        os.makedirs(course_folder_path, exist_ok=True)
        print(f"Created folder: {course_folder_path}")

if __name__ == "__main__":
    csv_file_path = "/content/drive/MyDrive/Final_Automation/courses_list.csv"
    panel_master_drive_path = "/content/drive/MyDrive/Final_Automation/panel_master"
    create_course_folders(csv_file_path, panel_master_drive_path)
# Out:
# Created folder: /content/drive/MyDrive/Final_Automation/panel_master/Face To Face Customer Service
# Created folder: /content/drive/MyDrive/Final_Automation/panel_master/How To Make It In The Corporate World
# Created folder: /content/drive/MyDrive/Final_Automation/panel_master/The Psychology Of Internet Addiction
# Created folder: /content/drive/MyDrive/Final_Automation/panel_master/Accountability
# Created folder: /content/drive/MyDrive/Final_Automation/panel_master/Managing Remote Teams
# Created folder: /content/drive/MyDrive/Final_Automation/panel_master/Advanced Interpersonal Skills
# Created folder: /content/drive/MyDrive/Final_Automation/panel_master/Managing Key Stakeholders
# Created folder: /content/drive/MyDrive/Final_Automation/panel_master/Building Business Relationships
# Created folder: /content/drive/MyDrive/Final_Automation/panel_master/Team Work
# Created folder: /content/drive/MyDrive/Final_Automation/panel_master/Detecting Forgery And Counterfeiting
# ...

# %% [markdown]
# # **Downloading MP3 Files and Renaming**

# %%
import csv
import requests
from google.colab import drive
import os
from tqdm import tqdm

def download_mp3(mp3_url, folder_drive_path, video_name, course_name, pbar):
    try:
        response = requests.get(mp3_url)
        response.raise_for_status()

        # Create the new file name based on the format: first 2 digits of "Video Name" - "Course_Name"
        new_mp3_name = f"{video_name[:2]}-{course_name}.mp3"
        mp3_drive_path = f"{folder_drive_path}/{new_mp3_name}"

        with open(mp3_drive_path, "wb") as mp3_file:
            mp3_file.write(response.content)

        pbar.update(1)  # Update the collective progress bar
    except requests.RequestException as e:
        print(f"Failed to download {mp3_url}. Error: {e}")

def download_and_rename_mp3(csv_file_drive_path, panel_master_drive_path):

    # Check if the panel_master directory exists in Google Drive
    full_panel_master_drive_path = panel_master_drive_path
    if not os.path.exists(full_panel_master_drive_path):
        print(f"Error: {panel_master_drive_path} directory not found in Google Drive.")
        return

    # Read the CSV file from Google Drive with tab delimiter
    with open(csv_file_drive_path, mode="r", encoding="utf-8") as csv_file:
        csv_reader = csv.DictReader(csv_file, delimiter=",")

        total_folders = len(os.listdir(full_panel_master_drive_path))
        with tqdm(total=total_folders, desc="MP3 Downloading", unit="Audio File") as pbar:
            for row in csv_reader:
                mp3_url = row['Mp3']
                course_name_csv = row['Course_Name']
                video_name_csv = row['Name']

                # Check if the course_name in the CSV file matches any of the folders in panel_master
                for folder_name in os.listdir(full_panel_master_drive_path):
                    if course_name_csv.lower() == folder_name.lower():
                        full_folder_drive_path = os.path.join(full_panel_master_drive_path, folder_name)

                        # Download the mp3 file into the respective folder with the new name in Google Drive
                        download_mp3(mp3_url, full_folder_drive_path, video_name_csv, course_name_csv, pbar)

if __name__ == "__main__":
    csv_file_drive_path = "/content/drive/MyDrive/Final_Automation/courses_list.csv"
    panel_master_drive_path = "/content/drive/MyDrive/Final_Automation/panel_master"
    download_and_rename_mp3(csv_file_drive_path, panel_master_drive_path)
# Out:
# MP3 Downloading: 52Audio File [03:37,  4.45s/Audio File]
# Failed to download https://zedny.blob.core.windows.net/courses/Mp3/Anger_and_Stress/02_Control_Your_Anger_and_Stress/10_Create_Space.mp3?sv=2018-03-28&sr=b&sig=%2Bz9JbDLUeiTAef8S0ojXVRhUZle9mGmDbHMcogrCdS4%3D&se=2028-04-30T14%3A52%3A40Z&sp=r. Error: 404 Client Error: The specified blob does not exist. for url: https://zedny.blob.core.windows.net/courses/Mp3/Anger_and_Stress/02_Control_Your_Anger_and_Stress/10_Create_Space.mp3?sv=2018-03-28&sr=b&sig=%2Bz9JbDLUeiTAef8S0ojXVRhUZle9mGmDbHMcogrCdS4%3D&se=2028-04-30T14%3A52%3A40Z&sp=r
# MP3 Downloading: 156Audio File [10:58,  4.01s/Audio File]
# ...

# %% [markdown]
# # Chunk Number 3:

# %% [markdown]
# # **Egyptian NLP References**

# %%
import docx
import os
import re
from tqdm import tqdm  # Import tqdm for progress bars

# Define the folder path and the output file name
folder_path = "/content/drive/MyDrive/Final_Automation/ref_scripts"
output_file = "/content/drive/MyDrive/Final_Automation/egy_reference/egy_reference.txt"

# Define the characters and numbers to be replaced with nothing
chars = ".?؟=@^$%&*#-_+/،,:!~\"'؛<>😊[]{}()"
nums = "0123456789٠١٢٣٤٥٦٧٨٩"

# Create an empty string to store the cleaned text
cleaned_text = ""

# Loop through the files in the folder
for file in tqdm(os.listdir(folder_path)):  # Wrap the file list with tqdm for a progress bar
    # Check if the file is a docx file
    if file.endswith(".docx"):
        # Open the file as a docx document
        doc = docx.Document(os.path.join(folder_path, file))
        # Loop through the paragraphs in the document
        for para in doc.paragraphs:
            # Get the text of each paragraph
            text = para.text
            # Check if the text has the letter p or P followed by a digit using a regular expression
            if not re.search("[pPvVlLsS]\d", text):
                # If not, replace each character and number in the text with nothing
                for c in chars + nums:
                    text = text.replace(c, "")
                # Replace double spaces with a single space
                text = re.sub("  ", " ", text)
                # Append the cleaned text to the cleaned_text string with a space separator
                cleaned_text += text.replace(".", "") + " "

# Write the cleaned text to the output file
with open(output_file, "w") as f:
    f.write(cleaned_text)
# Out:
# 100%|██████████| 100/100 [00:24<00:00,  4.02it/s]

# %% [markdown]
# # **Panel Master Restructuring Upon Redos**

# %%
import os
import shutil
from tqdm import tqdm

# Define the main directory path
main_folder_path = "/content/drive/MyDrive/Final_Automation/panel_master"

# Define the sub-folder suffix to check for
suffix_to_check = '- R'

# Define the destination folder paths
rrated_destination_folder_path = os.path.join(main_folder_path, 'R-Rated Courses')
grated_destination_folder_path = os.path.join(main_folder_path, 'G-Rated Courses')

# Create the destination folders if they don't exist
if not os.path.exists(rrated_destination_folder_path):
    os.makedirs(rrated_destination_folder_path)

if not os.path.exists(grated_destination_folder_path):
    os.makedirs(grated_destination_folder_path)

# Get a list of sub-folders in the main folder
sub_folders = [folder_name for folder_name in os.listdir(main_folder_path) if os.path.isdir(os.path.join(main_folder_path, folder_name))]

# Create a collective tqdm progress bar
with tqdm(total=len(sub_folders), desc="Moving Folders") as pbar:
    # Iterate through sub-folders in the main folder
    for folder_name in sub_folders:
        full_folder_path = os.path.join(main_folder_path, folder_name)

        # Check if it's a directory
        if os.path.isdir(full_folder_path):
            # Move to the appropriate destination folder based on the suffix
            if folder_name.endswith(suffix_to_check):
                shutil.move(full_folder_path, os.path.join(rrated_destination_folder_path, folder_name))
                pbar.set_postfix(Moved=f"'{folder_name}' to 'R-Rated Courses'")
            else:
                shutil.move(full_folder_path, os.path.join(grated_destination_folder_path, folder_name))
                pbar.set_postfix(Moved=f"'{folder_name}' to 'G-Rated Courses'")
            pbar.update(1)

print("Done Transferring the Rated Files")
# Out:
# Moving Folders:  99%|█████████▉| 96/97 [00:00<00:00, 194.38it/s, Moved='R-Rated Courses' to 'G-Rated Courses']
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/lib/python3.10/shutil.py in move(src, dst, copy_function)
#     815     try:
# --> 816         os.rename(src, real_dst)
#     817     except OSError:
#
# OSError: [Errno 22] Invalid argument: '/content/drive/MyDrive/Final_Automation/panel_master/G-Rated Courses' -> '/content/drive/MyDrive/Final_Automation/panel_master/G-Rated Courses/G-Rated Courses'
#
# During handling of the above exception, another exception occurred:
#
# Error                                     Traceback (most recent call last)
# <ipython-input-2-a9a3d186c0e8> in <cell line: 26>()
#      36                 pbar.set_postfix(Moved=f"'{folder_name}' to 'R-Rated Courses'")
#      37             else:
# ...

# %% [markdown]
# # Chunk Number 4:

# %%
import os
import shutil
from tqdm import tqdm

# Define the path to the "R-Rated Courses" folder
rrated_courses_folder = "/content/drive/MyDrive/Final_Automation/panel_master/R-Rated Courses"

# Get a list of sub-folders in the "R-Rated Courses" folder
sub_folders = [sub_folder_name for sub_folder_name in os.listdir(rrated_courses_folder) if os.path.isdir(os.path.join(rrated_courses_folder, sub_folder_name))]

# Create a tqdm progress bar
with tqdm(total=len(sub_folders), desc="Processing Sub-Folders") as pbar:
    for sub_folder_name in sub_folders:
        sub_folder_path = os.path.join(rrated_courses_folder, sub_folder_name)

        # Remove files ending with ".json" or ".docx"
        for filename in os.listdir(sub_folder_path):
            if filename.endswith('.json') or filename.endswith('.docx'):
                file_path = os.path.join(sub_folder_path, filename)
                os.remove(file_path)
                print(f"\nRemoved '{filename}' from '{sub_folder_name}'")

        # Access the "lectures_folder"
        lectures_folder_path = os.path.join(sub_folder_path, 'lectures_folder')

        # Check if "lectures_folder" exists
        if os.path.exists(lectures_folder_path):
            # Move all ".mp3" files from "lectures_folder" to the parent folder
            for mp3_filename in os.listdir(lectures_folder_path):
                if mp3_filename.endswith('.mp3'):
                    mp3_source_path = os.path.join(lectures_folder_path, mp3_filename)
                    mp3_destination_path = os.path.join(sub_folder_path, mp3_filename)
                    shutil.move(mp3_source_path, mp3_destination_path)

            # Check if "lectures_folder" is empty
            if not os.listdir(lectures_folder_path):
                # Remove the "lectures_folder" if it's empty
                os.rmdir(lectures_folder_path)
                print(f"Removed 'lectures_folder' in '{sub_folder_name}'")

        # Update the progress bar
        pbar.update(1)

print("Done Structuring the R-Rated & G-Rated Folders")
# Out:
# Processing Sub-Folders:   0%|          | 0/39 [00:00<?, ?it/s]
# Removed 'Time Management AltTranscriptions.docx' from 'Time Management - R'
#
# Removed 'Time Management Transcriptions.json' from 'Time Management - R'
# Processing Sub-Folders:   3%|▎         | 1/39 [00:00<00:17,  2.16it/s]
# Removed 'lectures_folder' in 'Time Management - R'
#
# Removed 'Ultimat Customer Service Skills AltTranscriptions.docx' from 'Ultimat Customer Service Skills - R'
#
# Removed 'Ultimat Customer Service Skills Transcriptions.json' from 'Ultimat Customer Service Skills - R'
# Processing Sub-Folders:   5%|▌         | 2/39 [00:00<00:17,  2.14it/s]
# Removed 'lectures_folder' in 'Ultimat Customer Service Skills - R'
#
# Removed 'Transition To Senior Management Transcriptions.json' from 'Transition To Senior Management - R'
#
# Removed 'Transition To Senior Management AltTranscriptions.docx' from 'Transition To Senior Management - R'
# ...

# %%
import os
from tqdm import tqdm

# Define the main directory path
main_folder_path = "/content/drive/MyDrive/Final_Automation/panel_master"

# Define the folder name for "R-Rated Courses"
rrated_folder_name = 'R-Rated Courses'

# Function to rename folders in the given directory
def rename_folders(directory_path, description):
    # Get a list of sub-folders
    sub_folders = [folder_name for folder_name in os.listdir(directory_path) if os.path.isdir(os.path.join(directory_path, folder_name))]

    # Create a tqdm progress bar
    with tqdm(total=len(sub_folders), desc=description) as pbar:
        # Iterate through folders in the directory
        for folder_name in sub_folders:
            full_folder_path = os.path.join(directory_path, folder_name)

            # Split the folder name using " - "
            folder_name_parts = folder_name.split(" - ")

            # Check if the split resulted in multiple parts
            if len(folder_name_parts) > 1:
                new_folder_name = folder_name_parts[0]  # Keep the first part
                new_full_folder_path = os.path.join(directory_path, new_folder_name)

                # Rename the folder
                os.rename(full_folder_path, new_full_folder_path)
                pbar.update(1)  # Update the progress bar
                pbar.set_postfix({"Renamed": new_folder_name})

# Rename folders in "R-Rated Courses" folder
rrated_folder_path = os.path.join(main_folder_path, rrated_folder_name)
rename_folders(rrated_folder_path, "Renaming 'R-Rated Courses' Folders")

print("Done Renaming Folders in 'R-Rated Courses'")
# Out:
# Renaming 'R-Rated Courses' Folders: 100%|██████████| 39/39 [00:00<00:00, 328.68it/s, Renamed=Leading At The Speed Of Trust]
# Done Renaming Folders in 'R-Rated Courses'

# %%
import os
from tqdm import tqdm

# Define the main directory path
main_folder_path = "/content/drive/MyDrive/Final_Automation/panel_master"

# Define the folder name for "R-Rated Courses"
rrated_folder_name = 'R-Rated Courses'

# Function to remove mp3 files from the given directory
def remove_mp3_files(directory_path, description):
    # Create a tqdm progress bar
    with tqdm(total=0, desc=description) as pbar:
        # Iterate through folders in the directory
        for root, _, files in os.walk(directory_path):
            for file_name in files:
                if file_name.endswith(".mp3"):
                    mp3_file_path = os.path.join(root, file_name)
                    os.remove(mp3_file_path)
                    pbar.update(1)  # Update the progress bar
                    pbar.set_postfix({"Removed": file_name})

# Remove mp3 files in "R-Rated Courses" sub-folders
rrated_folder_path = os.path.join(main_folder_path, rrated_folder_name)
remove_mp3_files(rrated_folder_path, "Removing MP3 Files in 'R-Rated Courses' Sub-Folders")

print("Done Removing MP3 Files")
# Out:
# Removing MP3 Files in 'R-Rated Courses' Sub-Folders: 0it [00:00, ?it/s]
# Done Removing MP3 Files

# %%
import os

# Define the main directory path
main_folder_path = "/content/drive/MyDrive/Final_Automation/panel_master"

# Define the folder name for "R-Rated Courses"
rrated_folder_name = 'R-Rated Courses'

# Function to check if a directory is empty
def is_directory_empty(directory_path):
    return not any(os.scandir(directory_path))

# Check if sub-folders in "R-Rated Courses" are empty
rrated_folder_path = os.path.join(main_folder_path, rrated_folder_name)

# Create a list to store the names of empty sub-folders
empty_subfolders = []

for subfolder_name in os.listdir(rrated_folder_path):
    subfolder_path = os.path.join(rrated_folder_path, subfolder_name)
    if os.path.isdir(subfolder_path) and is_directory_empty(subfolder_path):
        empty_subfolders.append(subfolder_name)

if empty_subfolders:
    print("Empty sub-folders in 'R-Rated Courses':")
    for subfolder_name in empty_subfolders:
        print(f"- {subfolder_name}")
else:
    print("No empty sub-folders in 'R-Rated Courses'")
# Out:
# Empty sub-folders in 'R-Rated Courses':
# - Time Management
# - Transition To Senior Management
# - Workplace Diversity
# - Writing Business Proposals Reports
# - The First 100 Days Magnet Plan
# - Team Building
# - Sustainability In Banking Sector
# - Anger And Stress
# - Stress Managment
# - Spin Selling
# - Communication Skills
# - Building Business Relationships
# - Building Customer Loyalty
# - Creativity And Innovation
# - Building Enhancing Resilience
# - Customer Service Basics
# - Body Language Fundamentals
# - Developing Civility At Work
# - Digital Transformation
# - Emotion Management
# - Face To Face Customer Service
# - Facilitating And Leading Effective Discussions
# - Flexibility And Adaptability
# - Selfmotivation
# - Selfconfidence Selfesteem
# - Sales Prospects
# - Proactivity
# - Managing Customer Expectations
# - Lateral Thinking
# - Learn And Master Sales
# - Logical Thinking
# - Influence Persuasion
# - Managing Multiple Generations In The Workplace
# ...

# %% [markdown]
# # Chunk Number 5:

# %% [markdown]
# # **Debugging Mode for Transcription with Reference Control**

# %%
from faster_whisper import WhisperModel
from typing import Tuple, Iterable
import imageio_ffmpeg as ffmpeg
from itertools import product
from docx import Document
from tqdm import tqdm
import pandas as pd
import difflib
import pickle
import shutil
import torch
import json
import os
import gc

idx = 0
# change egyption context among the new prompts
initial_prompt_options = [
    "_________________________________",
    'Transcribe this Egyptian speech into written text: هتشوف الحياة بطريقة مختلفة أوي عن الأول',
    'Transcribe this Egyptian speech into written text: طب لو أنا عايز أخس يبقى إيه هي المكملات اللي هتفيدني',
    'Transcribe this Egyptian speech into written text'
    ]

def transcribe_mp3_files_faster_whisper(panel_master_drive_path, csv_drive_path):
    def is_sentence_matched(paragraph, sentence):
          # Tokenize the paragraph and sentence into words
          paragraph_tokens = paragraph.split()
          sentence_tokens = sentence.split()

          # Initialize a matcher using SequenceMatcher
          matcher = difflib.SequenceMatcher(None, paragraph_tokens, sentence_tokens)

          # Get matching blocks (sequences of matching words)
          matching_blocks = matcher.get_matching_blocks()

          # Calculate the total length of matching words
          total_matched_length = sum(match.size for match in matching_blocks)

          # Determine if the sentence is matched
          sentence_length = len(sentence_tokens)
          return total_matched_length / sentence_length

    file_path = "/content/drive/MyDrive/Final_Automation/egy_reference/egy_reference.txt"
    with open(file_path, 'r', encoding='utf-8') as file:
        paragraph = file.read().replace("\n", ' ')

    global idx
    # Load CSV file from Google Drive to get the total file count
    df = pd.read_csv(csv_drive_path)
    if 'Course_Name' not in df.columns:
        print("Error: 'Course_Name' column missing in CSV!")
        return
    total_files = int(df['Course_Name'].nunique())
    print(f"Total unique courses in CSV: {total_files}")

    def has_transcription_json(folder_path):
        for filename in os.listdir(folder_path):
            if filename.endswith('Transcriptions.json'):
                return True
        return False

    for folder_name in os.listdir(panel_master_drive_path):
        full_folder_drive_path = os.path.join(panel_master_drive_path, folder_name)

        if full_folder_drive_path.endswith('.docx') or full_folder_drive_path.endswith('.txt') or full_folder_drive_path.endswith('.csv') or full_folder_drive_path.endswith(".ipynb_checkpoints"):
            continue

        mp3_files = [f for f in os.listdir(full_folder_drive_path) if f.lower().endswith('.mp3')]
        if len(mp3_files) == 0:
            print(f"No MP3 files found in {folder_name}")
            continue

        mp3_files.sort(key=lambda x: int(x.split("-")[0].strip()) if x.split("-")[0].strip().isdigit() else float('inf'))
        print(f"Found {len(mp3_files)} MP3 files in {folder_name}")

        # Initialize the model and load weights before processing MP3 files
        model_size = "large-v2"
        model = WhisperModel(model_size, device="cuda", compute_type="float16")

        mp3_files_progress = tqdm(mp3_files, desc=f"\nTranscribing {folder_name}", unit="File")
        course_transcription = {}

        for file_name in mp3_files_progress:
            full_file_drive_path = os.path.join(full_folder_drive_path, file_name)

            try:
                sql_id = int(file_name[:2])
            except ValueError:
                print(f"Error extracting SQL ID from {file_name}")
                continue
            print(f"Extracted SQL ID {sql_id} from {file_name}")

            course_name_parts = folder_name.split("-")
            course_name = course_name_parts[1].strip() if len(course_name_parts) > 1 else folder_name.strip()

            matching_rows = df[(df['Course_Name'] == course_name) & (df['Name'].str[:2] == str(sql_id).zfill(2))]
            if not matching_rows.empty:
                video_id = int(matching_rows['Id'].values[0])
                print(f"Matched video ID {video_id} for SQL ID {sql_id} in {course_name}")
            else:
                video_id = None
                print(f"No matching video ID found for SQL ID {sql_id} in {course_name}")
            flag = True
            while flag:
                segments_g, _ = model.transcribe(full_file_drive_path,
                                              vad_filter=True,
                                              beam_size = 11,
                                              best_of = 9,
                                              word_timestamps = True,
                                              no_speech_threshold = 0.2,
                                              vad_parameters = dict(min_silence_duration_ms = 2000),
                                              initial_prompt = initial_prompt_options[idx % len(initial_prompt_options)]
                                              )

                segments = []
                segment_id = 0
                for segment in segments_g:
                    segments.append({})
                    segments[segment_id]['start'] = segment.start
                    segments[segment_id]['end'] = segment.end
                    segments[segment_id]['text'] = segment.text
                    segment_id += 1

                ## if avg prob of segment matched egyption more than 50% will sucessed.
                summation_prob = 0
                for segment in segments:
                    summation_prob += is_sentence_matched(paragraph, segment['text'])
                avg_prob = summation_prob / len(segments)

                if avg_prob >= 0.3:
                    print(f"\nSuccessful initial sentence: {segments[0]['text']} of video_{sql_id} has avg_prob = {int(avg_prob*100)}%")
                    print(f"The initial prompt is: [ {initial_prompt_options[idx % len(initial_prompt_options)]} ]")
                    flag = False
                else:
                    print(f"FAILED at the initial sentence {segments[0]['text']} with avg_prob = {int(avg_prob * 100)}%")
                    print(f"The initial prompt is: [ {initial_prompt_options[idx % len(initial_prompt_options)]} ]")

                    # Condition override technique
                    user_input = input(f"\nDo you want to override and accept this as 0.6 matching? (y/n): ")
                    if user_input.lower() == 'y':
                        flag = False

                idx += 1

            if not segments:
                print(f"No segments/transcriptions found for {file_name}")
                continue

            entry_list = []
            view_index = 1
            for segment in segments:
                entry = {
                    "videoId": video_id,
                    "sqlId": sql_id,
                    "paragraphInfo": {
                        "id": "",
                        "viewIndex": view_index,
                        "startWord": "",
                        "endWord": "",
                        "startSecond": int(segment['start']),
                        "endSecond": int(segment['end']),
                        "paragraphDetails": segment['text'],
                        "objectiveId": "",
                        "skillsInfo": [
                            {
                                "skillId": ""
                            }
                        ]
                    }
                }
                entry_list.append(entry)
                view_index += 1

            if sql_id not in course_transcription:
                course_transcription[sql_id] = []
            course_transcription[sql_id].extend(entry_list)

        mp3_files_progress.close()

        # Release model memory and clear GPU cache
        gc.collect()
        del model
        torch.cuda.empty_cache()

        if not course_transcription:
            print(f"No transcriptions generated for {folder_name}")
            continue

        merged_doc = Document()
        for sql_id, entries in course_transcription.items():
            video_id_str = f"[V{sql_id}]"
            merged_doc.add_paragraph(video_id_str, style='Normal')
            for entry in entries:
                timestamp = f"Start: {entry['paragraphInfo']['startSecond']:.2f}s,  End: {entry['paragraphInfo']['endSecond']:.2f}s"
                merged_doc.add_paragraph(timestamp, style='Normal')
                merged_doc.add_paragraph(entry['paragraphInfo']['paragraphDetails'])

        merged_docx_drive_path = os.path.join(full_folder_drive_path, f"{folder_name} AltTranscriptions.docx")
        merged_doc.save(merged_docx_drive_path)
        print(f"Saved transcriptions for {folder_name} to {merged_docx_drive_path}")

        course_json_drive_path = os.path.join(full_folder_drive_path, f"{folder_name} Transcriptions.json")
        with open(course_json_drive_path, "w", encoding="utf-8") as json_file:
            json.dump(course_transcription, json_file, ensure_ascii=False, indent=4)
        print(f"Saved JSON for {folder_name} to {course_json_drive_path}")

        if has_transcription_json(full_folder_drive_path):
            lectures_folder_path = os.path.join(full_folder_drive_path, 'lectures_folder')
            if not os.path.exists(lectures_folder_path):
                os.mkdir(lectures_folder_path)
            for filename in os.listdir(full_folder_drive_path):
                file_path = os.path.join(full_folder_drive_path, filename)
                if filename.endswith('.mp3'):
                    shutil.move(file_path, os.path.join(lectures_folder_path, filename))

    print(f"Transcriptions for all courses completed successfully")

if __name__ == "__main__":
    panel_master_drive_path = "/content/drive/MyDrive/Final_Automation/panel_master/Lead"
    csv_drive_path = "/content/drive/MyDrive/Final_Automation/courses_list.csv"
    transcribe_mp3_files_faster_whisper(panel_master_drive_path, csv_drive_path)
# Out:
# Total unique courses in CSV: 99
# Found 10 MP3 files in Lead Yourself
# ...
# Transcribing Lead Yourself:   0%|          | 0/10 [00:00<?, ?File/s]
# Extracted SQL ID 1 from 01-Lead Yourself.mp3
# Matched video ID 963 for SQL ID 1 in Lead Yourself
# Transcribing Lead Yourself:  10%|█         | 1/10 [00:56<08:31, 56.85s/File]
# Successful initial sentence:  السيلف ليدرشيب أو قيادة الذات هو عامل أساسي من عوامل نجاحك وساعدتك كمان of video_1 has avg_prob = 74%
# The initial prompt is: [ _________________________________ ]
# Extracted SQL ID 2 from 02-Lead Yourself.mp3
# Matched video ID 962 for SQL ID 2 in Lead Yourself
# Transcribing Lead Yourself:  20%|██        | 2/10 [03:18<14:11, 106.46s/File]
# Successful initial sentence:  هل أحتاج أن أقود ذاتي؟ of video_2 has avg_prob = 77%
# The initial prompt is: [ Transcribe this Egyptian speech into written text: هتشوف الحياة بطريقة مختلفة أوي عن الأول ]
# Extracted SQL ID 3 from 03-Lead Yourself.mp3
# ...

# %% [markdown]
# # **Parameters Combinatiuons**

# %%
from faster_whisper import WhisperModel
from nltk.tokenize import word_tokenize
from typing import Tuple, Iterable
from itertools import product
from tqdm import tqdm
import pickle
import docx
import nltk
import os

# Download the necessary NLTK data (run this once)
nltk.download('punkt')

# Parameters Combinations
beam_size_options = [9,15]
best_of_options = [3,15]
temperature_options = [0.0, 0.4]
no_speech_threshold_options = [0.2, 0.5]
vad_filter = [True , False]
suppress_tokens_options = [[-1, 0], None]

# Define weights for quality and number of segments (you can adjust these)
quality_weight = 0.9
segments_weight = 0.8

# Specify the path to your DOCX file
docx_file_path = "/content/drive/MyDrive/voices/Resourses/01-Team_Work.mp3/egy_ref.docx"
doc = docx.Document(docx_file_path)

# Initialize the reference text
reference_text = ""

for paragraph in doc.paragraphs:
    reference_text += paragraph.text + "\n"  # Add a newline to separate paragraphs

# Tokenize the reference text into words using NLTK
reference_words = word_tokenize(reference_text)

# Define a function to calculate the combined score with quality evaluation
def calculate_combined_score(segments, quality_weight, segments_weight):
    # Tokenize the transcription into words using NLTK
    transcription_words = word_tokenize(" ".join(segment.text for segment in segments))

    # Calculate the number of common words between the reference and transcription
    common_words = set(reference_words) & set(transcription_words)

    # Calculate a quality score based on the number of common words
    quality_score = len(common_words) / len(reference_words)

    # Calculate the number of segments by converting the generator to a list
    num_segments = len(list(segments))

    # Calculate the combined score
    combined_score = (quality_weight * quality_score) + (segments_weight * num_segments)
    return combined_score

# Define hyperparameter names
hyperparameter_names = {
    'beam_size': beam_size_options,
    'best_of': best_of_options,
    'temperature': temperature_options,
    'no_speech_threshold': no_speech_threshold_options,
    'suppress_tokens': suppress_tokens_options,
    'vad_filter': vad_filter
}

# Initialize variables to store the best hyperparameters and the best score
best_hyperparameters = None
best_combined_score = float('-inf')  # Initialize with negative infinity for maximizing a score

# Directory to save the results
results_dir = "/content/drive/MyDrive/voices/results"
os.makedirs(results_dir, exist_ok=True)  # Create the directory if it doesn't exist

# Use tqdm to create a progress bar
total_combinations = (
    len(beam_size_options)
    * len(best_of_options)
    * len(temperature_options)
    * len(no_speech_threshold_options)
    * len(suppress_tokens_options)
    * len(vad_filter)
)

progress_bar = tqdm(total=total_combinations, desc="Grid Search Progress")

# Iterate through all combinations of hyperparameter values
for (
    beam_size, best_of,
    temperature,
    no_speech_threshold,
    suppress_tokens,
    vad_filter
) in product(
     beam_size_options, best_of_options,
     temperature_options,
     no_speech_threshold_options,
     suppress_tokens_options, vad_filter
):
    # Create a WhisperModel instance with the current hyperparameters
    model_size = "large-v2"
    model = WhisperModel(model_size, device="cuda", compute_type="default", )

    # Transcribe the audio using the current hyperparameters
    segments, info = model.transcribe(
        audio="/content/drive/MyDrive/voices/01-Team_Work.mp3",
        language = "ar",
        beam_size  =beam_size,
        best_of = best_of,
        temperature = temperature,
        no_speech_threshold = no_speech_threshold,
        condition_on_previous_text = True,
        suppress_tokens = suppress_tokens,
        word_timestamps = True,
        vad_filter = vad_filter ,
        vad_parameters = dict(min_silence_duration_ms = 2000)
    )

    # Calculate a score based on the model's performance
    combined_score = calculate_combined_score(segments, quality_weight, segments_weight)

    # Check if the current combination is better than the best found so far
    if combined_score > best_combined_score:
      best_combined_score = combined_score  # Update the best_combined_score
      best_hyperparameters = (
            beam_size,
            best_of,
            temperature,
            no_speech_threshold,
            suppress_tokens,
            vad_filter
    )

    best_segments = segments
    best_info = info

    # Update the best_score to combined_score
    best_score = combined_score

    # Create a filename for this combination
    filename = f"results_{beam_size}_{best_of}_{temperature}_{no_speech_threshold}_{suppress_tokens}.txt"
    filepath = os.path.join(results_dir, filename)

    # Save the best model results to a text file
    with open(filepath, "w") as result_file:
        result_file.write(f"Best Hyperparameters:\n")
        result_file.write(f"beam_size: {best_hyperparameters[0]}\n")
        result_file.write(f"best_of: {best_hyperparameters[1]}\n")
        result_file.write(f"temperature: {best_hyperparameters[2]}\n")
        result_file.write(f"no_speech_threshold: {best_hyperparameters[3]}\n")
        result_file.write(f"suppress_tokens: {best_hyperparameters[4]}\n")
        result_file.write(f"vad_filter: {best_hyperparameters[5]}\n")
        result_file.write(f"Best Score (Number of Segments Transcribed): {best_score}\n")
        result_file.write("Model Results:\n")
        for segment in best_segments:
            result_file.write(f"[{segment.start:.2f} -> {segment.end:.2f}] {segment.text}\n")

    # Update the progress bar
    progress_bar.update(1)

# Close the progress bar
progress_bar.close()

# Print the best hyperparameters and the corresponding combined score
print("Best Hyperparameters:")
print(f"beam_size: Selected: {best_hyperparameters[0]}, Options: {beam_size_options}")
print(f"best_of: Selected: {best_hyperparameters[1]}, Options: {best_of_options}")
print(f"temperature: Selected: {best_hyperparameters[2]}, Options: {temperature_options}")
print(f"no_speech_threshold: Selected: {best_hyperparameters[3]}, Options: {no_speech_threshold_options}")
print(f"suppress_tokens: Selected: {best_hyperparameters[4]}, Options: {suppress_tokens_options}")
print(f"vad_filter: Selected: {best_hyperparameters[5]}, Options: {vad_filter}")
print("Best Combined Score (Quality + Segments):", best_combined_score)

# Save the best hyperparameters and score to a file using pickle
best_results = {
    "best_hyperparameters": best_hyperparameters,
    "best_score": best_score,
}

with open("best_results.pkl", "wb") as f:
    pickle.dump(best_results, f)

# You can also print or analyze the best segments and info as needed
for segment in best_segments:
    print("[%.2fs -> %.2fs] %s" % (segment.start, segment.end, segment.text))

# %% [markdown]
# # **Looping on content_files and restructure panel_master**
# ###### Add the "content_files" directory

# %%
import os
import shutil

# Define source and destination directories
source_directory = "/content/drive/MyDrive/Final_Automation/content_files"
destination_directory = "/content/drive/MyDrive/Final_Automation/panel_master"

# Get a list of files in the source directory
files_to_move = os.listdir(source_directory)

# Loop through files and move them
for filename in files_to_move:
    # Check if the file is an xlsx or docx file
    if filename.endswith('.xlsx') or filename.endswith('.docx'):
        # Extract the base file name (without extension)
        file_base_name = os.path.splitext(filename)[0]

        # Create the expected folder name in the destination directory
        expected_folder_name = os.path.join(destination_directory, file_base_name)

        # Check if the folder with the same name exists in the destination directory
        if os.path.exists(expected_folder_name):
            # Move the file to the corresponding folder
            shutil.move(os.path.join(source_directory, filename), expected_folder_name)
        else:
            # If the folder doesn't exist, create it and then move the file
            os.makedirs(expected_folder_name)
            shutil.move(os.path.join(source_directory, filename), expected_folder_name)

# Provide a summary and handle any potential errors
print("File move operation completed successfully!")

try:
    # Remove the source directory if it's empty (all files are moved)
    os.rmdir(source_directory)
except OSError:
    print(f"Warning: Unable to remove source directory '{source_directory}' as it may not be empty.")
# Out:
# File move operation completed successfully!

# %% [markdown]
# # Chunk Number 6:

# %% [markdown]
# # **Document Analysis Phase**

# %%
import os
import re
from docx import Document
import json

def pyillam_script_final(docx_file_path):
    document = Document(docx_file_path)
    text = "\n".join([paragraph.text for paragraph in document.paragraphs]).strip().lower()

    lines = text.split('\n')
    final_lines = [i.strip() for i in lines if len(i) > 1]

    v_list = []
    video_info = []
    titles = []
    for i, element in enumerate(final_lines):
        if re.search(r'v\d', element):
            v_list.append(i)

    for video_index in v_list:
        v_line = final_lines[video_index].strip()
        v_index = v_line[v_line.find('v') + 1]
        video_title = final_lines[video_index + 1].strip().title()
        titles.append(video_title)
        video_info.append({'video_index': v_index, 'video_title': video_title})

    script = [title for title in final_lines if title.lower() not in [t.lower() for t in titles]]

    v_trimmed_list = [j for j, j_element in enumerate(script) if re.search(r'v\d', j_element)]
    v_trimmed_list.append(len(script))

    paragraphs = [script[start_idx:end_idx][1:] for start_idx, end_idx in zip(v_trimmed_list[:-1], v_trimmed_list[1:])]

    index_lists = [[int(re.search(r'\[p(\d+)\]', element).group(1)) for element in sub_list if re.search(r'\[p(\d+)\]', element)] for sub_list in paragraphs]
    videos_list = [[jendex for jendex, element in enumerate(sub_list) if re.search(r'\[p(\d+)\]', element)] for sub_list in paragraphs]

    for sub_list in paragraphs:
        sub_list.append(len(sub_list))

    paragraphs_result = []
    for i in range(len(index_lists)):
        paragraphs_result.append({'videoId': i + 1, 'video_title': video_info[i]['video_title'], 'paragraphInfo': []})
        paragraphs_counter = 1
        for j in range(len(videos_list[i])):
            start = videos_list[i][j] + 1
            end = videos_list[i][j + 1] if j + 1 < len(videos_list[i]) else -1
            paragraphs_result[i]['paragraphInfo'].append({'viewIndex': paragraphs_counter, 'paragraphDetails': " ".join(paragraphs[i][start:end])})
            paragraphs_counter += 1

    return paragraphs_result

def process_docx_files_final(panel_master_drive_path):
    for folder_name in os.listdir(panel_master_drive_path):
        full_folder_drive_path = os.path.join(panel_master_drive_path, folder_name)

        # Check if the folder contains a .docx file with the folder's name
        docx_file_path = os.path.join(full_folder_drive_path, f"{folder_name}.docx")
        if os.path.isfile(docx_file_path):
            script_result = pyillam_script_final(docx_file_path)

            # Save as a JSON file
            json_file_path = os.path.join(full_folder_drive_path, f"{folder_name} Script.json")
            with open(json_file_path, "w", encoding="utf-8") as json_file:
                json.dump(script_result, json_file, ensure_ascii=False, indent=4)

panel_master_drive_path = "/content/drive/MyDrive/Final_Automation/trialone"
process_docx_files_final(panel_master_drive_path)

# %% [markdown]
# # **Excel File Analysis**

# %%
import pandas as pd
import json
import re
import os

full_panel_master_drive_path = "/content/drive/MyDrive/Final_Automation/trialone"

def extract_number(text):
    match = re.search(r'\d+', str(text))
    return int(match.group()) if match else None

def is_numeric(text):
    try:
        float(text)
        return True
    except ValueError:
        return False

def get_correct_choices(right_answer, num_choices):
    correct_choices = []
    if not pd.isna(right_answer) and isinstance(right_answer, str):
        try:
            digits = [int(digit) for digit in re.findall(r'\d', right_answer)]
            for digit in digits:
                if 1 <= digit <= num_choices:
                    correct_choices.append(digit)
        except ValueError:
            pass
    return correct_choices

for folder in os.listdir(full_panel_master_drive_path):
    full_folder_drive_path = os.path.join(full_panel_master_drive_path, folder)

    if os.path.isdir(full_folder_drive_path):
        for file in os.listdir(full_folder_drive_path):
            if file.endswith('.xlsx'):
                full_xlsx_path = os.path.join(full_folder_drive_path, file)
                df = pd.read_excel(full_xlsx_path)
                df.columns = df.columns.str.lower()

                def pyillam_excelinfo():
                    questions_info = []
                    for index, row in df.iterrows():
                        # alternative = int(row['alt']) if not pd.isna(row['alt']) else None
                        questionTypeId = str(row['question type'])

                        if questionTypeId.lower() == "true&false":
                            questionTypeId = 1
                        else:
                            questionTypeId = 2

                        question_info = {
                            "id": "",
                            "questionTypeId": questionTypeId,
                            "question_videoId": extract_number(row['v']),
                            "question_paragraph": extract_number(row['p']),
                            "questionDetails": None if pd.isna(row.get('question', None)) else row['question'],
                            "timeLimit": 45,
                            "skipping": False,
                            "preAssessment": is_numeric(row['c']),
                            "chapter": extract_number(row['c']) if is_numeric(row['c']) else None,
                            "finalExam": not is_numeric(row['c']),
                            "pathways": True,
                            "games": True,
                            "alternative": 0,
                            "questions_skills_objectives": [
                                {
                                    "skill_Id": extract_number(row['s']),
                                    "objective_Id": extract_number(row['l']),
                                    "level_Id": ""
                                }
                            ],
                            "questionAnswers": []
                        }

                        total_points = 10 if question_info['questions_skills_objectives'][0]['level_Id'] in [1, 2] else 20 if question_info['questions_skills_objectives'][0]['level_Id'] in [3, 4] else 30
                        print(df.columns)
                        correct_choices = get_correct_choices(row['right answer'], 6)
                        correct_choices_num = len(correct_choices)

                        if str(row['question type']).lower() == "select":
                            for i in range(1, 7):
                                choice = row.get(f'choice {i}', None)
                                answers = None if pd.isna(choice) else choice
                                point = total_points // correct_choices_num if i in correct_choices else 0

                                if i in correct_choices:
                                    correctAnswers = answers
                                else:
                                    correct_answer_index = correct_choices[0]
                                    correctAnswers = row.get(f'choice {correct_answer_index}', None)

                                question_info["questionAnswers"].append({
                                    "viewIndex": i,
                                    "answers": answers,
                                    "correctAnswers": correctAnswers,
                                    "point": point
                                })

                        elif str(row['question type']).lower() == "mcq":
                            for i in range(1, 5):
                                choice = row.get(f'choice {i}', None)
                                answers = None if pd.isna(choice) else choice
                                point = total_points // correct_choices_num if i in correct_choices else 0

                                if i in correct_choices:
                                    correctAnswers = answers
                                else:
                                    correct_answer_index = correct_choices[0]
                                    correctAnswers = row.get(f'choice {correct_answer_index}', None)

                                question_info["questionAnswers"].append({
                                    "viewIndex": i,
                                    "answers": answers,
                                    "correctAnswers": correctAnswers,
                                    "point": point
                                })

                        else:
                            for i in range(1, 3):
                                choice = row.get(f'choice {i}', None)
                                # Modify this line to set "answers" as "True" or "False"
                                if isinstance(choice, bool):
                                    answers = "True" if choice else "False"
                                else:
                                    answers = "True" if choice and choice == "True" else "False"
                                point = total_points if i in correct_choices else 0

                                if correct_choices:  # Check if correct_choices is not empty
                                    if i in correct_choices:
                                        correctAnswers = "True"  # Set as string "true" if correct
                                    else:
                                        correctAnswers = "False"  # Set as string "false" if incorrect
                                else:
                                    # Handle the case where there are no correct choices
                                    correctAnswers = "False"  # Default to "false" if no correct choices

                                question_info["questionAnswers"].append({
                                    "viewIndex": i,
                                    "answers": answers,
                                    "correctAnswers": correctAnswers,
                                    "point": point
                                })

                        questions_info.append(question_info)

                    course_title = df.iloc[0]['course name']
                    json_structure = {
                        "course title": course_title,
                        "questionsInfo": questions_info
                    }

                    questions_info_json = json.dumps(json_structure, indent=4, ensure_ascii=False)
                    return questions_info_json

                json_data = pyillam_excelinfo()

                if json_data:
                    folder_name = os.path.basename(full_folder_drive_path)
                    json_file_name = f"{folder_name} Quiz.json"
                    json_file_path = os.path.join(full_folder_drive_path, json_file_name)
                    with open(json_file_path, 'w', encoding='utf-8') as json_file:
                        json_file.write(json_data)
# Out:
# Streaming output truncated to the last 5000 lines.
# Index(['course name', 'c', 'v', 'p', 'l', 's', 'alt', 'question level',
#        'question', 'question type', 'choice 1', 'choice 2', 'choice 3',
#        'choice 4', 'choice 5', 'choice 6', 'right answer'],
#       dtype='object')
# Index(['course name', 'c', 'v', 'p', 'l', 's', 'alt', 'question level',
#        'question', 'question type', 'choice 1', 'choice 2', 'choice 3',
#        'choice 4', 'choice 5', 'choice 6', 'right answer'],
#       dtype='object')
# Index(['course name', 'c', 'v', 'p', 'l', 's', 'alt', 'question level',
#        'question', 'question type', 'choice 1', 'choice 2', 'choice 3',
#        'choice 4', 'choice 5', 'choice 6', 'right answer'],
#       dtype='object')
# Index(['course name', 'c', 'v', 'p', 'l', 's', 'alt', 'question level',
#        'question', 'question type', 'choice 1', 'choice 2', 'choice 3',
#        'choice 4', 'choice 5', 'choice 6', 'right answer'],
#       dtype='object')
# ...

# %%
import pandas as pd
import json
import re
import os

## Extracting Skills and Objectives in each course

# Define the path to the main folder
full_panel_master_drive_path = "/content/drive/MyDrive/Final_Automation/trialone"

# Iterate through sub-folders in the main folder
for folder in os.listdir(full_panel_master_drive_path):
    full_folder_drive_path = os.path.join(full_panel_master_drive_path, folder)

    # Check if the item in the main folder is a sub-folder
    if os.path.isdir(full_folder_drive_path):
        # Initialize dictionaries
        map_objective_item = {}
        map_S_item = {}

        # Iterate through files in the sub-folder
        for file in os.listdir(full_folder_drive_path):
            # Check if the file is an xlsx file
            if file.endswith('.xlsx'):
                # Construct the full path to the xlsx file
                full_xlsx_path = os.path.join(full_folder_drive_path, file)

                # Load and process the xlsx file
                df = pd.read_excel(full_xlsx_path, sheet_name=1)
                df.columns = df.columns.str.lower()


                # Iterate through the rows of the DataFrame and populate the dictionaries
                for index, row in df.iterrows():
                    if pd.notna(row['index']):
                        current_index = row['index']
                        if any(char.lower() == 'l' for char in current_index) and any(char.isdigit() for char in current_index):
                            # Check if the index contains 'l' or 'L' and a digit
                            digit_index = ''.join(filter(str.isdigit, current_index))  # Extract digits
                            if digit_index not in map_objective_item:
                                map_objective_item[digit_index] = str(row['item (english)']).strip()  # Convert to string
                            else:
                                # If the key already exists, concatenate the strings with a separator (e.g., comma)
                                map_objective_item[digit_index] += ', ' + str(row['item (english)'])
                        elif any(char.lower() == 's' for char in current_index) and any(char.isdigit() for char in current_index):
                            # Check if the index contains 's' or 'S' and a digit
                            digit_index = ''.join(filter(str.isdigit, current_index))  # Extract digits
                            if digit_index not in map_S_item:
                                map_S_item[digit_index] = str(row['item (english)']).strip()  # Convert to string
                            else:
                                # If the key already exists, concatenate the strings with a separator (e.g., comma)
                                map_S_item[digit_index] += ', ' + str(row['item (english)'])
                        else:
                            # Handle indices that don't contain 'L'/'l' or 'S'/'s' followed by digits
                            pass

        # Create and save the JSON files in the same directory as the xlsx file
        skills_json_filename = os.path.join(full_folder_drive_path, f"{folder} Skills.json")
        objectives_json_filename = os.path.join(full_folder_drive_path, f"{folder} Objectives.json")

        with open(skills_json_filename, 'w') as skills_json_file:
            json.dump(map_S_item, skills_json_file, indent=4)

        with open(objectives_json_filename, 'w') as objectives_json_file:
            json.dump(map_objective_item, objectives_json_file, indent=4)

# %%
import os
import json

## Create the Updated Questions File with the Skills & Objective Matrix

# Define the main directory path
main_directory = '/content/drive/MyDrive/Final_Automation/trialone'

# Loop through sub-folders in the main directory
for root, _, files in os.walk(main_directory):
    for file in files:
        if file.endswith('Quiz.json'):
            quiz_file_path = os.path.join(root, file)

            # Extract folder name from the path
            folder_name = os.path.basename(root)

            # Create dictionaries to store skill and objective mappings
            skill_id_mapping = {}
            objective_id_mapping = {}

            # Create the corresponding Skills and Objectives file paths
            skills_file_path = os.path.join(root, folder_name + ' Skills.json')
            objectives_file_path = os.path.join(root, folder_name + ' Objectives.json')

            # Check if the Skills file exists
            if os.path.exists(skills_file_path):
                # Read the Skills JSON file
                with open(skills_file_path, 'r', encoding='utf-8') as skills_file:
                    skills_data = json.load(skills_file)

                # Update the skill_id_mapping dictionary
                skill_id_mapping.update({
                    str(skill_id): skill_name for skill_id, skill_name in skills_data.items()
                })

            # Check if the Objectives file exists
            if os.path.exists(objectives_file_path):
                # Read the Objectives JSON file
                with open(objectives_file_path, 'r', encoding='utf-8') as objectives_file:
                    objectives_data = json.load(objectives_file)

                # Update the objective_id_mapping dictionary
                objective_id_mapping.update({
                    str(objective_id): objective_name for objective_id, objective_name in objectives_data.items()
                })

            # Read the Quiz JSON file
            with open(quiz_file_path, 'r', encoding='utf-8') as quiz_file:
                quiz_data = json.load(quiz_file)

            # Iterate through the questionsInfo list and update the "skill_Id" and "objective_Id" fields
            for question in quiz_data['questionsInfo']:
                skill_id = str(question['questions_skills_objectives'][0]['skill_Id'])
                if skill_id in skill_id_mapping:
                    question['questions_skills_objectives'][0]['skill_Id'] = skill_id_mapping[skill_id]

                objective_id = str(question['questions_skills_objectives'][0]['objective_Id'])
                if objective_id in objective_id_mapping:
                    question['questions_skills_objectives'][0]['objective_Id'] = objective_id_mapping[objective_id]

            # Define the output file path for updated quiz
            output_file_path = os.path.join(root, f'{folder_name} Updated Questions.json')

            # Write the updated data to the output quiz file
            with open(output_file_path, 'w', encoding='utf-8') as updated_quiz_file:
                json.dump(quiz_data, updated_quiz_file, ensure_ascii=False, indent=4)

            print(f"Updated Questions JSON for {folder_name} saved to {output_file_path}")

            # Create a JSON file to store the combined skill and objective mappings for this course
            combined_mappings = {
                'course_skills': skill_id_mapping,
                'course_objectives': objective_id_mapping
            }

            # Define the output file path for the combined mappings
            combined_mappings_file_path = os.path.join(root, f'{folder_name} Skills&Objectives.json')

            # Write the combined mappings to the output file
            with open(combined_mappings_file_path, 'w', encoding='utf-8') as combined_mappings_file:
                json.dump(combined_mappings, combined_mappings_file, ensure_ascii=False, indent=4)

            print(f"Combined mappings for {folder_name} saved to {combined_mappings_file_path}")

print("Processing completed.")
# Out:
# Updated Questions JSON for Accountability saved to /content/drive/MyDrive/Final_Automation/trialone/Accountability/Accountability Updated Questions.json
# Combined mappings for Accountability saved to /content/drive/MyDrive/Final_Automation/trialone/Accountability/Accountability Skills&Objectives.json
# Updated Questions JSON for Art of Coaching saved to /content/drive/MyDrive/Final_Automation/trialone/Art of Coaching/Art of Coaching Updated Questions.json
# Combined mappings for Art of Coaching saved to /content/drive/MyDrive/Final_Automation/trialone/Art of Coaching/Art of Coaching Skills&Objectives.json
# Updated Questions JSON for Attention To Details saved to /content/drive/MyDrive/Final_Automation/trialone/Attention To Details/Attention To Details Updated Questions.json
# Combined mappings for Attention To Details saved to /content/drive/MyDrive/Final_Automation/trialone/Attention To Details/Attention To Details Skills&Objectives.json
# ...

# %% [markdown]
# # Chunk Number 7:

# %% [markdown]
# # **Final Matching**

# %%
import os
import json
import time
import difflib

def transform_data_to_desired_format(script_data, transcriptions_data, questions_data):

    def is_sentence_matched(paragraph, sentence):
        # Tokenize the paragraph and sentence into words
        paragraph_tokens = paragraph.split()
        sentence_tokens = sentence.split()

        # Initialize a matcher using SequenceMatcher
        matcher = difflib.SequenceMatcher(None, paragraph_tokens, sentence_tokens)

        # Get matching b|locks (sequences of matching words)
        matching_blocks = matcher.get_matching_blocks()

        # Calculate the total length of matching words
        total_matched_length = sum(match.size for match in matching_blocks)

        # Determine if the sentence is matched (you can set a threshold as needed)
        sentence_length = len(sentence_tokens)
        return total_matched_length / sentence_length

    final_result = []

    for video_key, transcriptions in transcriptions_data.items():
        video_title = next((video['video_title'] for video in script_data if video['videoId'] == int(video_key)), 'Default Video Title')
        video_data = {
            "videoId": transcriptions[0]['videoId'],
            "video_title": video_title,
            "sqlId": 1,
            "paragraphInfo": []
        }

        for paragraph_info in script_data:
            if paragraph_info['videoId'] == int(video_key):
                for paragraph_data in paragraph_info['paragraphInfo']:
                    updated_paragraph_data = {
                        "id": "",
                        "viewIndex": paragraph_data['viewIndex'],
                        "startWord": " ".join(paragraph_data['paragraphDetails'].split()[:2]),
                        "endWord": " ".join(paragraph_data['paragraphDetails'].split()[-2:]),
                        "startSecond": None,
                        "endSecond": None,
                        "paragraphDetails": paragraph_data['paragraphDetails'],
                        "objectiveId": "",
                        "skillsInfo": [{"skillId": ""}],
                        "questionsInfo": []
                    }

                    # print("Actual Paragraph:", paragraph_data['paragraphDetails'])
                    for transcription in transcriptions:
                        sentence = transcription['paragraphInfo']['paragraphDetails']
                        l = len(sentence)
                        # print("Actual Sentence:", sentence)
                        if is_sentence_matched(paragraph_data['paragraphDetails'], sentence) >= 0.7:
                            start_second = transcription['paragraphInfo']['startSecond']
                            end_second = transcription['paragraphInfo']['endSecond']

                            if updated_paragraph_data['startSecond'] is None or updated_paragraph_data['startSecond'] > start_second:
                                updated_paragraph_data['startSecond'] = start_second

                            if updated_paragraph_data['endSecond'] is None or updated_paragraph_data['endSecond'] < end_second:
                                updated_paragraph_data['endSecond'] = end_second

                    for question_info in questions_data['questionsInfo']:
                        if question_info['question_videoId'] == paragraph_info['videoId'] and question_info['question_paragraph'] == paragraph_data['viewIndex']:
                            skills_objectives = question_info.get('questions_skills_objectives', [{}])[0]
                            updated_paragraph_data['objectiveId'] = skills_objectives.get('objective_Id', None)
                            updated_paragraph_data['skillsInfo'][0]['skillId'] = skills_objectives.get('skill_Id', None)

                            updated_question_info = {
                                "id": "",
                                "questionTypeId": question_info['questionTypeId'],
                                "questionDetails": question_info['questionDetails'],
                                "timeLimit": question_info['timeLimit'],
                                "skipping": question_info['skipping'],
                                "preAssessment": question_info['preAssessment'],
                                "chapter": not question_info['finalExam'],
                                "finalExam": question_info['finalExam'],
                                "pathways": question_info['pathways'],
                                "games": question_info['games'],
                                "alternative": question_info['alternative'],
                                "questionsSkills": [{"skillId": skills_objectives.get('skill_Id', None)}],
                                "questionAnswers": question_info['questionAnswers']
                            }
                            updated_paragraph_data['questionsInfo'].append(updated_question_info)

                    video_data['paragraphInfo'].append(updated_paragraph_data)
        final_result.append(video_data)
        # print('*' * 50)
    return final_result

def process_subfolder(subfolder_path):
    # Get the folder name from the subfolder path
    folder_name = os.path.basename(subfolder_path)

    # Check for JSON files with specific suffixes in the subfolder
    script_file_path = os.path.join(subfolder_path, f"{folder_name} Script.json")
    transcriptions_file_path = os.path.join(subfolder_path, f"{folder_name} Transcriptions.json")
    questions_file_path = os.path.join(subfolder_path, f"{folder_name} Updated Questions.json")

    # Check if all required JSON files exist
    if os.path.exists(script_file_path) and os.path.exists(transcriptions_file_path) and os.path.exists(questions_file_path):
        # Load the JSON files
        with open(script_file_path, "r") as script_file:
            script_data = json.load(script_file)

        with open(transcriptions_file_path, "r") as transcriptions_file:
            transcriptions_data = json.load(transcriptions_file)

        with open(questions_file_path, "r") as questions_file:
            questions_data = json.load(questions_file)

        # Transform the data using the new logic
        transformed_data = transform_data_to_desired_format(script_data, transcriptions_data, questions_data)

        # Define the output file path
        output_file_path = os.path.join(subfolder_path, f"{folder_name} Final.json")

        # Save the transformed data to a JSON file
        with open(output_file_path, "w", encoding="utf-8") as output_file:
            json.dump(transformed_data, output_file, ensure_ascii=False, indent=4)

        print(f"Transformed data saved to: {output_file_path}")
    else:
        print(f"Required JSON files not found in subfolder: {subfolder_path}")

def main():
    # Define the root directory
    root_directory = "/content/drive/MyDrive/Final_Automation/trialone"

    # Loop through all sub-folders in the root directory
    for subfolder_name in os.listdir(root_directory):
        subfolder_path = os.path.join(root_directory, subfolder_name)

        # Check if the item is a directory
        if os.path.isdir(subfolder_path):
            process_subfolder(subfolder_path)

if __name__ == "__main__":
    main()
# Out:
# Transformed data saved to: /content/drive/MyDrive/Final_Automation/trialone/Accountability/Accountability Final.json
# Transformed data saved to: /content/drive/MyDrive/Final_Automation/trialone/Attention To Details/Attention To Details Final.json
# Transformed data saved to: /content/drive/MyDrive/Final_Automation/trialone/Digital Marketing Fundementals/Digital Marketing Fundementals Final.json
# Transformed data saved to: /content/drive/MyDrive/Final_Automation/trialone/Interviewing Skills/Interviewing Skills Final.json
# Transformed data saved to: /content/drive/MyDrive/Final_Automation/trialone/Introduction To Waste Management In Egypt/Introduction To Waste Management In Egypt Final.json
# Transformed data saved to: /content/drive/MyDrive/Final_Automation/trialone/Lead Yourself/Lead Yourself Final.json
# Transformed data saved to: /content/drive/MyDrive/Final_Automation/trialone/Marketing Fundementals/Marketing Fundementals Final.json
# ...

# %%
import json
import os

def format_paragraph_info(paragraph):
    default_paragraph = {
        "id": "",
        "viewIndex": 0,
        "startWord": "",
        "endWord": "",
        "startSecond": 0,
        "endSecond": 0,
        "paragraphDetails": "",
        "objectiveId": "",
        "skillsInfo": [],
        "questionsInfo": []
    }
    formatted_paragraph = {key: paragraph.get(key, default_paragraph[key]) for key in default_paragraph}
    formatted_paragraph["startSecond"] = paragraph.get("startSecond", 0) or 0
    formatted_paragraph["endSecond"] = paragraph.get("endSecond", 0) or 0
    formatted_paragraph["skillsInfo"] = [skill for skill in paragraph.get("skillsInfo", []) if skill.get("skillId")]
    formatted_paragraph["questionsInfo"] = [format_question_info(question) for question in paragraph.get("questionsInfo", [])]
    return formatted_paragraph

def format_question_info(question):
    default_question = {
        "id": "",
        "questionTypeId": 0,
        "questionDetails": "",
        "timeLimit": 0,
        "skipping": True,
        "preAssessment": True,
        "chapter": True,
        "finalExam": True,
        "pathways": True,
        "games": True,
        "alternative": 0,
        "questionsSkills": [],
        "questionAnswers": []
    }
    formatted_question = {key: question.get(key, default_question[key]) for key in default_question}
    formatted_question["questionAnswers"] = [
        {
            "viewIndex": ans.get("viewIndex", 0),
            "answers": ans.get("answers", "") or "",
            "correctAnswers": ans.get("correctAnswers", "") or "",
            "point": ans.get("point", 0) or 0
        }
        for ans in question.get("questionAnswers", [])
    ]
    return formatted_question

def transform_json_content(json_content):
    formatted_content = []
    for video in json_content:
        formatted_video = {
            "videoId": video["videoId"],
            "video_title": video["video_title"],
            "paragraphInfo": [format_paragraph_info(paragraph) for paragraph in video.get("paragraphInfo", [])]
        }
        formatted_content.append(formatted_video)
    filtered_content = [video for video in formatted_content if video["paragraphInfo"]]
    return {"videosScriptsInfo": filtered_content}

def process_json_file(json_file_path):
    with open(json_file_path, "r", encoding='utf-8') as file:
        json_content = json.load(file)
        transformed_content = transform_json_content(json_content)

    with open(json_file_path, "w", encoding='utf-8') as output_file:
        json.dump(transformed_content, output_file, ensure_ascii=False, indent=4)

def process_all_json_files_in_folder(folder_path):
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith("Final.json"):
                json_file_path = os.path.join(root, file)
                process_json_file(json_file_path)

trialone_folder_path = "/content/drive/MyDrive/Final_Automation/trialone"

# Process all JSON files in the specified folder and its subfolders
process_all_json_files_in_folder(trialone_folder_path)

# %% [markdown]
# # **Cleaning & Structuring Prior to the Post Request**

# %%
import os
import shutil

# Define the root directory
root_directory = "/content/drive/MyDrive/Final_Automation/panel_master"

# Define the sub-folder names for organizing files
used_files_folder_name = "used_files"
asset_files_folder_name = "asset_files"

# Loop through all sub-folders in the root directory
for folder_name in os.listdir(root_directory):
    folder_path = os.path.join(root_directory, folder_name)

    # Check if the item is a directory
    if os.path.isdir(folder_path):
        # Check for file extensions and organize them
        for filename in os.listdir(folder_path):
            file_path = os.path.join(folder_path, filename)

            # Check for "{folder name}.xlsx" or "{folder name}.docx" or "Skills.json" or "Objectives.json" or more extensions
            if filename.endswith(f"{folder_name}.xlsx") or filename.endswith(f"{folder_name}.docx") or filename.endswith("Skills.json") or filename.endswith(" Objectives.json") or filename.endswith("Quiz.json"):
                # Create the "used_files" folder in the same directory if it doesn't exist
                used_files_folder_path = os.path.join(folder_path, used_files_folder_name)
                os.makedirs(used_files_folder_path, exist_ok=True)

                # Move the file to the "used_files" folder
                shutil.move(file_path, os.path.join(used_files_folder_path, filename))

                print(f"Moved {filename} to {used_files_folder_name} in {folder_name}")

            # Check for "Transcriptions.json" or "Script.json" or "Questions.json"
            elif filename.endswith("Transcriptions.json") or filename.endswith("Script.json") or filename.endswith("Questions.json") or filename.endswith("Transcriptions.docx"):
                # Create the "asset_files" folder in the same directory if it doesn't exist
                asset_files_folder_path = os.path.join(folder_path, asset_files_folder_name)
                os.makedirs(asset_files_folder_path, exist_ok=True)

                # Move the file to the "asset_files" folder
                shutil.move(file_path, os.path.join(asset_files_folder_path, filename))

                print(f"Moved {filename} to {asset_files_folder_name} in {folder_name}")
# Out:
# Moved Managing Customer Expectations AltTranscriptions.docx to asset_files in Managing Customer Expectations
# Moved Managing Customer Expectations Transcriptions.json to asset_files in Managing Customer Expectations
# Moved Managing Customer Expectations.docx to used_files in Managing Customer Expectations
# Moved Managing Customer Expectations.xlsx to used_files in Managing Customer Expectations
# Moved Managing Customer Expectations Script.json to asset_files in Managing Customer Expectations
# Moved Managing Customer Expectations Quiz.json to used_files in Managing Customer Expectations
# Moved Managing Customer Expectations Skills.json to used_files in Managing Customer Expectations
# Moved Managing Customer Expectations Objectives.json to used_files in Managing Customer Expectations
# Moved Managing Customer Expectations Updated Questions.json to asset_files in Managing Customer Expectations
# Moved Selfmotivation AltTranscriptions.docx to asset_files in Selfmotivation
# ...

# %% [markdown]
# # **System Post Requests**

# %%
import os
import requests
import json

def post_json_data_from_file(api_url, json_file_path):
    try:
        with open(json_file_path, "r") as json_file:
            json_payload = json.load(json_file)

        # Make the POST request with JSON data without any headers
        response = requests.post(api_url, json=json_payload)

        # Check if the request was successful (HTTP status code 200)
        if response.status_code == 200:
            # Parse the response JSON and return it
            response_data = response.json()
            return response_data
        else:
            print(f"POST request failed with status code {response.status_code}. Response: {response.text}")
            return None

    except requests.RequestException as e:
        print(f"POST Request Failed. Error: {e}")
        return None

# Specify the path to your JSON file here
json_file_path = "/content/drive/MyDrive/Final_Automation/trialone/Attention To Details/Attention To Details Final.json"

if os.path.exists(json_file_path):
    print(f"Found JSON file: {json_file_path}")
    api_url = ""
    response_data = post_json_data_from_file(api_url, json_file_path)

    if response_data:
        print("POST request successful!")
        print("Response:", response_data)
else:
    print("JSON file not found.")
# Out:
# Found JSON file: /content/drive/MyDrive/Final_Automation/trialone/Attention To Details/Attention To Details Final.json
# POST request failed with status code 400. Response: {"type":"https://tools.ietf.org/html/rfc7231#section-6.5.1","title":"One or more validation errors occurred.","status":400,"traceId":"00-50f369bb38c99a2a7702d46f7b0e8f42-d888e452cfe1c557-00","errors":{"receivedData":["The receivedData field is required."],"$.videosScriptsInfo[4].paragraphInfo[0].questionsInfo[0].questionAnswers[0].answers":["The JSON value could not be converted to System.String. Path: $.videosScriptsInfo[4].paragraphInfo[0].questionsInfo[0].questionAnswers[0].answers | LineNumber: 0 | BytePositionInLine: 81792."]}}
